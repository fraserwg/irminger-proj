# %%
from pathlib import Path
import numpy as np
import xarray as xr

# %%
ensemble_path = Path("/work/n01/n01/fwg/irminger-proj/data/interim/ensemble.zarr")
ds = xr.open_dataset(ensemble_path, engine="zarr")
ds
# Out:
# <xarray.Dataset>
# Dimensions:        (YC: 1, XC: 6000, Z: 500, Zp1: 501, run: 37, time: 168,
#                     XG: 6000, YG: 1, Zl: 500, Zu: 500)
# Coordinates: (12/35)
#     Depth          (YC, XC) float32 ...
#     PHrefC         (Z) float32 ...
#     PHrefF         (Zp1) float32 ...
#   * XC             (XC) float32 12.5 37.5 62.5 ... 1.499e+05 1.5e+05 1.5e+05
#   * XG             (XG) float32 0.0 25.0 50.0 75.0 ... 1.499e+05 1.5e+05 1.5e+05
#   * YC             (YC) float32 12.5
#     ...             ...
#     rAs            (YG, XC) float32 ...
#     rAw            (YC, XG) float32 ...
#     rAz            (YG, XG) float32 ...
#     rhoRef         (Z) float32 ...
#   * run            (run) int64 0 6 7 8 9 11 12 13 14 ... 41 42 43 44 46 47 48 49
#   * time           (time) timedelta64[ns] 0 days 00:00:00 ... 20 days 21:00:00
# Data variables:
#     RHOAnoma       (run, time, Z, YC, XC) float32 ...
#     TOTTTEND       (run, time, Z, YC, XC) float32 ...
# ...

# %%
days = 24 * 60 * 60

# %%
ds.where(np.isclose(ds["wind_duration"], 1.25 * days, atol=days))

# %%
np.isclose(ds["wind_duration"], 1.25 * days, atol=days)
# Out:
# array([False,  True, False, False, False,  True, False, False, False,
#         True, False, False, False,  True, False, False, False,  True,
#        False, False, False,  True, False, False, False,  True, False,
#        False, False,  True, False, False, False,  True, False, False,
#        False])

# %%
ds["run"].where(np.isclose(ds["wind_duration"], 1.25 * days, atol=days), drop=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /work/n01/n01/fwg/irminger-proj/src/post_processing/understanding_mld.ipynb Cell 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Barcher2/work/n01/n01/fwg/irminger-proj/src/post_processing/understanding_mld.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> ds["run"].where(np.isclose(ds["wind_duration"], 1.25 * days, atol=days), drop=True)
#
# File /work/n01/n01/fwg/irminger-proj/irminger-proj/lib/python3.8/site-packages/xarray/core/common.py:1056, in DataWithCoords.where(self, cond, other, drop)
#    1054 if drop:
#    1055     if not isinstance(cond, (Dataset, DataArray)):
# -> 1056         raise TypeError(
#    1057             f"cond argument is {cond!r} but must be a {Dataset!r} or {DataArray!r}"
#    1058         )
#    1060     self, cond = align(self, cond)  # type: ignore[assignment]
# ...

# %%
np.isclose(0, [10, 20, 120], atol=100)
# Out:
# array([ True,  True, False])

# %%
np.isclose?
# Out:
# Signature: np.isclose(a, b, rtol=1e-05, atol=1e-08, equal_nan=False)
# Docstring:
# Returns a boolean array where two arrays are element-wise equal within a
# tolerance.
#
# The tolerance values are positive, typically very small numbers.  The
# relative difference (`rtol` * abs(`b`)) and the absolute difference
# `atol` are added together to compare against the absolute difference
# between `a` and `b`.
#
# .. warning:: The default `atol` is not appropriate for comparing numbers
#              that are much smaller than one (see Notes).
#
# Parameters
# ----------
# a, b : array_like
#     Input arrays to compare.
# rtol : float
#     The relative tolerance parameter (see Notes).
# atol : float
#     The absolute tolerance parameter (see Notes).
# equal_nan : bool
#     Whether to compare NaN's as equal.  If True, NaN's in `a` will be
#     considered equal to NaN's in `b` in the output array.
#
# Returns
# -------
# y : array_like
# ...
